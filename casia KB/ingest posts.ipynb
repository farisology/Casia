# %%
import psycopg2
from datetime import datetime

# %%
# Connect to the Postgres database
db = psycopg2.connect(
--
)

# Create a postgres cursor object
cursor = db.cursor()

# %%
# Define the MySQL query to insert data into the table
query = "INSERT INTO posts (created_at, title, short_description, description, image_s3_uri) VALUES (%s, %s, %s, %s, %s)"

title = "How to Grow and Care for Oxalis"
short_description = "Oxalis, often referred to as Shamrocks or Lucky Clover, is a versatile and captivating genus with over 550 species. Identified by their clover-like or butterfly wing-shaped leaves, these diminutive plants bring a touch of whimsy to your garden or home."
description = """<p>Oxalis, often referred to as Shamrocks or Lucky Clover, is a versatile and captivating genus with over 550 species. Identified by their clover-like or butterfly wing-shaped leaves, these diminutive plants bring a touch of whimsy to your garden or home. The alluring aesthetics of Oxalis, combined with their intriguing habit of folding their leaves closed at night, make them a delightful and energizing addition to any green space. </p>
<p>Before you dive into planting Oxalis, remember to check with your local extension service, as some species, like Oxalis pes-caprae L., are considered invasive in certain regions.</p>

<h2>Planting Oxalis: An Excursion into Cool Shades</h2>
<p>Oxalis thrives best in areas with mild winters and cool summers. It prefers north-facing locations that receive afternoon shade, making it a fitting choice for those less sunny spots in your garden. For houseplant enthusiasts, Oxalis corms can be started indoors in autumn and provide an energizing burst of green during the winter months.</p>
<p>Planting instructions vary depending on the method of propagation. But in general, corms should be planted vertically, spaced 3- to 4-inches apart, and 1- to 1 1/2-inches deep.</p>

<h2>Caring for Oxalis: Emulating Nature's Blueprint</h2>
<p>The key to keeping Oxalis thriving is simulating their native conditions. Here's what you need to consider:</p>
<ul>
<li><strong>Light:</strong> Oxalis typically prefers bright, indirect light in the morning and benefits from afternoon shade. This mimics their natural understory habitat and protects them from extreme heat.</li>
<li><strong>Soil:</strong> Emulate their natural woodland or highland soils by using a fertile, well-draining soil with a slightly acidic pH.</li>
<li><strong>Water:</strong> Oxalis prefers it on the dry side, mirroring the conditions of a well-drained forest floor.</li>
<li><strong>Temperature and Humidity:</strong> Oxalis generally thrives in temperatures between 60 and 75 degrees Fahrenheit, depending on the species.</li>
<li><strong>Fertilizer:</strong> Oxalis benefits most from soil enriched with organic nutrients, replicating the nutrient-rich decay of a woodland setting.</li>
</ul>

<h2>The Aesthetic and Energetic Appeal of Oxalis</h2>
<p>Aside from being relatively easy to care for, Oxalis brings an energizing aesthetic appeal to your garden or home:</p>
<ul>
<li><strong>Vibrant Hues:</strong> With colors spanning from white to yellow, and shades of red, pink, and purple, Oxalis introduces a vibrant array of colors into your space.</li>
<li><strong>Dynamic Energy:</strong> Oxalis' unique habit of opening its leaves to greet the day and folding them close at night adds a dynamic, almost sentient energy to your space.</li>
<li><strong>Flexible Aesthetics:</strong> From species with variegated leaves to those that offer solid green or deep purplish-red foliage, Oxalis adds a textured, layered aesthetic that complements other plants in your garden or home.</li>
</ul>

<h2>Common Challenges and Solutions</h2>
<ul>
<li><strong>Failure to Bloom:</strong> If your Oxalis is failing to bloom, consider adjusting the light conditions or provide more nutrients through fertilizing.</li>
<li><strong>Fungal Diseases:</strong> Avoid overwatering and ensure well-drained soil to prevent common fungal diseases.</li>
<li><strong>Pests:</strong> Regularly inspect your plant for common pests like aphids, spider mites, and whiteflies.</li>
</ul>

<h2>Conclusion</h2>
<p>Incorporating Oxalis into your indoor or outdoor green space not only adds an aesthetically pleasing element but also a dynamic, energetic presence that can invigorate your day. With the right care, you can enjoy the captivating charm of these plants all year round.</p>
"""
image_s3_uri = "https://casia-artefacts-bucket.s3.ap-southeast-1.amazonaws.com/Oxalis.jpg"
# Loop through each row of the dataframe and insert it into the table
values = (datetime.now(),
          title,
          short_description,
          description,
          image_s3_uri
         )
cursor.execute(query, values)
db.commit()

# Close the MySQL connection
db.close()

# %%
# Define the MySQL query to insert data into the table
query = "INSERT INTO posts (created_at, title, short_description, description, image_s3_uri) VALUES (%s, %s, %s, %s, %s)"

title = "The Vibrancy of Tropical Hibiscus: A Mesmerizing Display of Energy and Aesthetics"
short_description = "The tropical hibiscus, a beacon of energy and exotic beauty, is a standout choice for those desiring an infusion of dramatic vibrancy in their gardens. With its remarkable, trumpet-shaped flowers expanding up to 6 inches in diameter, this stunning plant showcases a visual spectacle that's nothing short of mesmerizing"
description ="""<p>The tropical hibiscus, a beacon of energy and exotic beauty, is a standout choice for those desiring an infusion of dramatic vibrancy in their gardens. With its remarkable, trumpet-shaped flowers expanding up to 6 inches in diameter, this stunning plant showcases a visual spectacle that's nothing short of mesmerizing.</p>

<h2>Energetic Growth</h2>

<p>The vitality of the tropical hibiscus is awe-inspiring. This fast-growing, energetic plant can add up to 24 inches per year, potentially reaching a height of 15 feet under ideal conditions. A native of Asia, it constantly produces a profusion of flowers, bringing a palpable sense of dynamism to your garden. Despite each individual bloom lasting just a day, the plant’s capacity for continuous flowering ensures an unending splash of color that energizes the surroundings.</p>

<h2>Aesthetic Allure</h2>

<p>The aesthetic allure of the tropical hibiscus is indisputable. Boasting a palette ranging from pure white to rich reds, soft pinks, vibrant oranges, bright yellows, and regal purples, the plant's flowers are nothing short of an artist’s dream. The stamens protrude dramatically from the center of the flowers, accentuating their aesthetic appeal. The foliage, too, contributes to the plant's overall beauty, with glossy green leaves providing the perfect backdrop for the vivid blooms.</p>

<h2>Care Instructions</h2>

<h3>Light</h3>

<p>While a tropical plant like hibiscus loves the sun, it's more nuanced than that. In northern climates, your hibiscus plants will be happiest in full sun. However, if you live somewhere that's hotter and dry, you're better off putting your plant in a location that gets partial shade.</p>

<h3>Soil</h3>

<p>If you're growing your hibiscus plant in a container, use a well-drained potting mix as the soil, preferably one formulated for tropical plants. In the ground, your soil should have lots of organic matter and should be well-draining to help avoid the risk of root rot.</p>

<h3>Water</h3>

<p>Tropical hibiscus is a thirsty plant and will thrive and produce blossoms only if it is given enough water. Depending on the heat, wind, and humidity in your environment, your plant may need to be watered daily, or even twice a day in extremely dry conditions. Typically, tropical hibiscus plants thrive best with 1 to 2 inches of water per week.</p>

<h3>Fertilizer</h3>

<p>When you buy a potted hibiscus, it likely has a slow-release fertilizer mixed into the soil, so it will not require additional feeding in the first few months. After that, regular feeding with a diluted fish emulsion fertilizer will keep it blooming vigorously.</p>

<h2>In Conclusion</h2>

<p>The tropical hibiscus is not just a plant—it's a powerful statement of energy, vitality, and visual spectacle. By choosing the tropical hibiscus, you are choosing a living piece of art that continually changes and energizes the space it inhabits. With proper care and attention, you can cultivate a dynamic, vibrant garden that is as resilient as it is beautiful.</p>
"""

image_s3_uri = "https://casia-artefacts-bucket.s3.ap-southeast-1.amazonaws.com/hibiscus-5219091_1280.jpg"
# Loop through each row of the dataframe and insert it into the table
values = (datetime.now(),
          title,
          short_description,
          description,
          image_s3_uri
         )

cursor.execute(query, values)
db.commit()

# Close the MySQL connection
db.close()

# %%
# Define the MySQL query to insert data into the table
query = "INSERT INTO posts (created_at, title, short_description, description, image_s3_uri) VALUES (%s, %s, %s, %s, %s)"

title = "Anthurium andraeanum: A Pop of Tropical Color"

short_description = "Anthurium andraeanum, commonly known as the flamingo flower or laceleaf, is a beautiful evergreen plant that is most known for its gorgeous flowers. Originally from the rainforests of Ecuador and Colombia, this plant has since become a favorite indoor and outdoor plant around the world."

description ="""<p>Anthurium andraeanum, commonly known as the flamingo flower or laceleaf, is a beautiful evergreen plant that is most known for its gorgeous flowers. Originally from the rainforests of Ecuador and Colombia, this plant has since become a favorite indoor and outdoor plant around the world.</p>

<h2>Characteristics and Features</h2>

<p>Anthurium plants are notable for their broad, heart-shaped, shiny green leaves and their spectacular bright red, pink, or white heart-shaped flowers. But what's more interesting is that what most people assume to be the flower is actually a modified leaf, called a spathe, which can be shiny and vibrantly colored. The actual flowers are small bumps on the spadix, the elongated, fleshy projection rising from the base of the spathe.</p>

<p>These tropical plants can grow up to 1.5 feet tall and wide, with their glossy, leathery leaves reaching up to 9 inches long. The flowers bloom throughout the year and last for several weeks, offering a long-lasting pop of color to your home or garden.</p>

<h2>Care and Maintenance</h2>

<p>Flamingo flowers are relatively easy to care for, making them a great choice for novice and experienced gardeners alike. They prefer a warm, humid environment mimicking their tropical origin. If you live in USDA hardiness zones 10 or higher, you can grow anthuriums outdoors. However, they make an excellent houseplant in less ideal climates.</p>

<p>When it comes to light, anthuriums prefer bright, indirect light. Direct sunlight can burn the leaves, causing brown, dry spots. As for watering, these plants prefer to dry out slightly between watering. Overwatering can lead to root rot. They prefer high humidity, so it's beneficial to mist the plant regularly or keep it in a naturally humid room like the bathroom or kitchen.</p>

<p>The soil needs to be rich but well-draining. A mixture of peat moss, pine bark, and perlite is usually a good choice.</p> 

<p>Feeding your anthurium with a phosphorus-rich fertilizer every 3-4 months will encourage it to bloom. Prune away dead or yellowing leaves and spent flowers to keep the plant looking its best.</p>

<h2>Important to Know</h2>

<p>While Anthurium andraeanum is a beautiful addition to your home, it's important to know that all parts of the plant are toxic if ingested both to humans and pets, including dogs and cats. Be sure to keep it out of reach of children and curious pets.</p>

<p>In conclusion, the flamingo flower, with its vibrant and long-lasting blooms, is a great addition to any home or garden. Its minimal care requirements make it a perfect choice for both beginner and expert gardeners.</p>
"""

image_s3_uri = "https://casia-artefacts-bucket.s3.ap-southeast-1.amazonaws.com/flamingo-flower-4349272_1280.jpg"
# Loop through each row of the dataframe and insert it into the table
values = (datetime.now(),
          title,
          short_description,
          description,
          image_s3_uri
         )

cursor.execute(query, values)
db.commit()

# Close the MySQL connection
db.close()

# %%
# Define the MySQL query to insert data into the table
query = "INSERT INTO posts (created_at, title, short_description, description, image_s3_uri) VALUES (%s, %s, %s, %s, %s)"

title = "Monstera Deliciosa: The Iconic Swiss Cheese Plant"

short_description = "Monstera deliciosa, more commonly known as the Swiss Cheese Plant, has been a favorite houseplant for many years. With its large, glossy green leaves featuring distinctive holes and notches, it's a striking addition to any indoor plant collection."

description ="""<p>Monstera deliciosa, more commonly known as the Swiss Cheese Plant, has been a favorite houseplant for many years. With its large, glossy green leaves featuring distinctive holes and notches, it's a striking addition to any indoor plant collection. This Central American native has the potential to grow into an impressive, tree-sized spectacle with the right care.</p>

<h2>Characteristics and Features</h2>

<p>Monstera deliciosa is a climbing plant in the wild, often ascending 20 meters or more into the rainforest canopy. Its leaves are the plant's most striking feature. When immature, the leaves are smaller and whole, but as they mature, they develop characteristic splits and holes that have given the plant its nickname. In nature, these holes and splits help the plant resist strong winds and intense tropical rains.</p>

<p>In addition to its stunning foliage, Monstera deliciosa is also known for its unique fruit, which is said to taste like a mix of banana, pineapple, and mango. However, it's important to note that the fruit should only be eaten when fully ripe, as it contains oxalic acid when unripe and can be irritating to the skin and mouth.</p>

<h2>Care and Maintenance</h2>

<p>Monstera deliciosa enjoys conditions that mimic its natural rainforest habitat. It thrives in bright, indirect light and in a warm, humid environment. It can tolerate some shade but will show slower growth and fewer fenestrations (the holes and splits in the leaves) in lower light levels.</p>

<p>Water your Monstera deliciosa when the top inch of the soil is dry, usually once a week in the growing season and less in winter. It prefers a peat-based potting soil that drains well. The plant also benefits from a trellis or pole to support its climbing growth habit.</p>

<p>Monstera deliciosa can benefit from a balanced liquid houseplant fertilizer every two weeks during the growing season. In winter, reduce feeding to once a month.</p>

<h2>Important to Know</h2>

<p>While a wonderful addition to the home, all parts of the Monstera deliciosa are toxic when ingested due to calcium oxalate crystals. This includes the unripe fruit. It should be kept out of reach from pets and small children.</p>

<p>In conclusion, the Monstera deliciosa, with its distinctive, lush foliage, makes a stunning addition to any indoor space. Its relatively straightforward care requirements make it a favorite among both novice and seasoned houseplant owners.</p>

"""

image_s3_uri = "https://casia-artefacts-bucket.s3.ap-southeast-1.amazonaws.com/monsera-7975344_1280.jpg"
# Loop through each row of the dataframe and insert it into the table
values = (datetime.now(),
          title,
          short_description,
          description,
          image_s3_uri
         )

cursor.execute(query, values)
db.commit()

# Close the MySQL connection
db.close()
